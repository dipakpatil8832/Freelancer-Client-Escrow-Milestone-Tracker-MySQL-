# %%
import pandas as pd

# %%
df= pd.read_csv("D:\Inno Batch 485\SQL\SQL project 1\deatasets for sql project 1\disputes.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dispute_id         610 non-null    int64
#  1   milestone_id       610 non-null    int64
#  2   dispute_date       610 non-null    object
#  3   dispute_reason     610 non-null    object
#  4   resolution_status  610 non-null    object
#  5   resolved_date      318 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 28.7+ KB

# %%
df["project_id"].duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# dispute_id           0
# milestone_id         0
# dispute_date         0
# dispute_reason       0
# resolution_status    0
# resolved_date        0
# dtype: int64

# %%
import numpy as np
df["resolved_date"].fillna("NULL",inplace=True)

# %%
df.to_csv("disputes_1.csv",index=False)
